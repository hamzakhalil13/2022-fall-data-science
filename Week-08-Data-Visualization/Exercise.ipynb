# %%
! ls data/
# Out:
# BX-Police.csv     Sales.csv         budget-sample.csv
# Iris.csv          Stocks.csv

# %%
import pandas as pd
import numpy as np

import seaborn as sns
sns.set()


import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Using budget-sample.csv
# * Plot a histogram of the base_salary.  Write one sentence about what this tells you about base salaries.
# * Make a boxplot of base salaries, what does this tell you about base salaries?
# * Make a boxplot of base salaries per (or by) work_location_borough, what does this tell you about the difference in working in each location?
# * Make a plot visualizing the difference average base salaries based on agency_name.  Who would you want to work for based on this information?
# <br><br>
# * __Tell me something new, cool, and interesting about this data__

# %%
df = pd.read_csv('data/budget-sample.csv')
df.head()
# Out:
#    fiscal_year  payroll_number                     agency_name  last_name  \
# 0         2020             826  DEPT OF ENVIRONMENT PROTECTION      BROWN
# 1         2020              56               POLICE DEPARTMENT       WONG
# 2         2020             742          DEPT OF ED PEDAGOGICAL    FARRELL
# 3         2020             827        DEPARTMENT OF SANITATION  ATTANASIO
# 4         2020             744   DEPT OF ED PARA PROFESSIONALS     MCNEIL
#
#   first_name mid_init agency_start_date work_location_borough  \
# 0   TRACYANN      NaN        02/23/2004                QUEENS
# 1     CHIWAI      NaN        07/08/2015              BROOKLYN
# 2       TARA        E        09/09/1996             MANHATTAN
# 3     JOSEPH      NaN        10/18/1999                QUEENS
# 4     GLORIA        D        09/28/1989             MANHATTAN
#
#            title_description leave_status_as_of_june_30  base_salary  \
# 0        COMMUNITY ASSISTANT                     ACTIVE      37816.0
# ...

# %%
sns.histplot(data= df, x = 'base_salary')

# %%
#base salaries are not normally distributed

# %%
sns.boxplot(data = df, x = 'base_salary')

# %%
#A lot of outliers where salaries are high

# %%
sns.boxplot(data = df, x = "base_salary", y = "work_location_borough")

# %%
#Manhattan has the highest outliers in terms of salary and it has the highest median
#Brooklyn and Queens are pretty similar in terms of outliers and base salaries
#Bronx has the least outliers

# %%
# Make a plot visualizing the difference average base salaries based on agency_name.  
#Who would you want to work for based on this information?

agency_group = df.groupby('agency_name')
agency_base_salary = agency_group['base_salary'].mean().sort_values()
agency_base_salary.plot(kind = 'barh', figsize =(20,20))

# %%
print('Based on the information it would be smart to work for the FDNY but then again we dont know how accurate this data is')
# Out:
# Based on the information it would be smart to work for the FDNY but then again we dont know how accurate this data is

# %% [markdown]
# # Using the BX-Police.csv data:
# * create a time series chart illustrating their average base salary over time (by fiscal_year).
# * What trend does this show?
# * Why do you think the trend exists?

# %%
police_df = pd.read_csv('data/BX-Police.csv' )
df.head()
# Out:
#    fiscal_year  payroll_number                     agency_name  last_name  \
# 0         2020             826  DEPT OF ENVIRONMENT PROTECTION      BROWN
# 1         2020              56               POLICE DEPARTMENT       WONG
# 2         2020             742          DEPT OF ED PEDAGOGICAL    FARRELL
# 3         2020             827        DEPARTMENT OF SANITATION  ATTANASIO
# 4         2020             744   DEPT OF ED PARA PROFESSIONALS     MCNEIL
#
#   first_name mid_init agency_start_date work_location_borough  \
# 0   TRACYANN      NaN        02/23/2004                QUEENS
# 1     CHIWAI      NaN        07/08/2015              BROOKLYN
# 2       TARA        E        09/09/1996             MANHATTAN
# 3     JOSEPH      NaN        10/18/1999                QUEENS
# 4     GLORIA        D        09/28/1989             MANHATTAN
#
#            title_description leave_status_as_of_june_30  base_salary  \
# 0        COMMUNITY ASSISTANT                     ACTIVE      37816.0
# ...

# %%
year = police_df.groupby('fiscal_year')
fiscal_salary = year['base_salary'].mean()

# %%
fiscal_salary.plot(kind= 'line', figsize = (6,6))

# %%
print('Trends i see is salary tends to increase the longer you stay employed and the downward trend in 2019 could \n be a result of defunding the police')
# Out:
# Trends i see is salary tends to increase the longer you stay employed and the downward trend in 2019 could
#  be a result of defunding the police

# %% [markdown]
# # Using Stocks.csv
# * Tell me a story about the Google stock for the year.
# * Any story you'd like to tell.

# %%
google_df = pd.read_csv('data/Stocks.csv')
google_df
# Out:
#            Date   Volume         High          Low         Open        Close  \
# 0    2021-01-04  1901900  1760.650024  1707.849976  1757.540039  1728.239990
# 1    2021-01-05  1145300  1747.670044  1718.015015  1725.000000  1740.920044
# 2    2021-01-06  2602100  1748.000000  1699.000000  1702.630005  1735.290039
# 3    2021-01-07  2265000  1788.400024  1737.050049  1740.060059  1787.250000
# 4    2021-01-08  2050600  1809.839966  1773.535034  1787.979980  1807.209961
# ..          ...      ...          ...          ...          ...          ...
# 247  2021-12-27   662800  2968.530029  2945.000000  2949.270020  2961.280029
# 248  2021-12-28   931200  2967.489990  2918.709961  2967.489990  2928.959961
# 249  2021-12-29   851100  2943.675049  2910.090088  2928.590088  2930.090088
# 250  2021-12-30   648900  2941.250000  2915.169922  2929.000000  2920.050049
# 251  2021-12-31   864900  2927.300049  2893.550049  2910.879883  2893.590088
#
#        Adj Close Ticker
# ...

# %%
date = google_df.groupby('Date')
close = date['Close'].mean()
close.plot(kind='line', figsize= (10,10))

# %%
print('Google stock price increased in the year of 2021')
# Out:
# Google stock price increased in the year of 2021

# %% [markdown]
# # Using Sales.csv
# * make a time series chart that shows the sales for each item over the past 12 months.
# * What does this tell you about the items.
# * Which item would you recommend they push more of and which item/s would you recommend they stop selling?
# * show what percentage of each item contributes to total sales.

# %%
df = pd.read_csv('data/Sales.csv')
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer
# ...

# %%
cols = list(df.columns)
cols.remove('month_number')
cols
# Out:
# ['facecream',
#  'facewash',
#  'toothpaste',
#  'bathingsoap',
#  'shampoo',
#  'moisturizer']

# %%
df.plot(x='month_number', y=cols,figsize=(10,10))

# %%
print('Bathing Soap sells the most and it sells more towards the end of the year')
print('Toothpaste sells the second most and has a similar trend as Bathing soap')
print('The other items sell lower and have somewhat of a normal sales throughout the year')
print('Moisturizer and facewash sell exactly the same throughout the year')
# Out:
# Bathing Soap sells the most and it sells more towards the end of the year
# Toothpaste sells the second most and has a similar trend as Bathing soap
# The other items sell lower and have somewhat of a normal sales throughout the year
# Moisturizer and facewash sell exactly the same throughout the year

# %%
print('I would recommend to sell and push Bathing soap and toothpaste and stop selling moisturizer and facewash')
# Out:
# I would recommend to sell and push Bathing soap and maybe avoid moisturizer

# %%
per = df[cols].sum() / df[cols].sum().sum()
per *= 100
per
# Out:
# facecream      12.277453
# facewash        6.592722
# toothpaste     24.893178
# bathingsoap    40.596069
# shampoo         9.047856
# moisturizer     6.592722
# dtype: float64

# %%
# help(plt.pie)
plt.pie(x = per, labels = cols, autopct='%.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7fe1dc3d1100>,
# ...
#  [Text(1.0191857113582774, 0.4138363030995739, 'facecream'),
#   Text(0.614065570010269, 0.9126464133101954, 'facewash'),
#   Text(-0.4252111998343268, 1.0144926986112084, 'toothpaste'),
#   Text(-0.6978921207722792, -0.8502626581027599, 'bathingsoap'),
#   Text(0.8424026833130699, -0.7073596815955373, 'shampoo'),
#   Text(1.07649072018405, -0.22620285002100654, 'moisturizer')],
#  [Text(0.5559194789226967, 0.22572889259976756, '12%'),
#   Text(0.33494485636923754, 0.49780713453283376, '7%'),
#   Text(-0.2319333817278146, 0.5533596537879318, '25%'),
#   Text(-0.38066842951215224, -0.46377963169241443, '41%'),
#   Text(0.4594923727162199, -0.38583255359756574, '9%'),
#   Text(0.5871767564640271, -0.12338337273873083, '7%')])
